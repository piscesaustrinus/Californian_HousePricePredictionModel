# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['median_house_value'], axis=1)
y = data ['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6740     -118.09     34.12                38.0       1713.0           285.0
# 7945     -118.14     33.87                44.0       1661.0           315.0
# 1706     -122.32     37.95                37.0       1887.0           353.0
# 10361    -117.66     33.57                16.0       4277.0           565.0
# 13950    -117.07     34.24                21.0       4773.0          1047.0
# ...          ...       ...                 ...          ...             ...
# 19651    -120.87     37.50                 7.0       4966.0           985.0
# 20355    -118.96     34.19                16.0       1807.0           346.0
# 5531     -118.41     33.97                44.0       2789.0           503.0
# 16378    -121.29     38.02                12.0       2006.0           426.0
# 11943    -117.43     33.95                36.0       2284.0           444.0
#
#        population  households  median_income ocean_proximity  \
# 6740        779.0       286.0         5.6152       <1H OCEAN
# 7945        985.0       319.0         4.3942       <1H OCEAN
# 1706        895.0       359.0         4.4500        NEAR BAY
# 10361      1642.0       549.0         8.0082       <1H OCEAN
# 13950       337.0       130.0         3.9375          INLAND
# ...           ...         ...            ...             ...
# 19651      2431.0       904.0         3.1042          INLAND
# 20355       587.0       296.0         1.9811       <1H OCEAN
# 5531       3732.0       474.0         4.6176       <1H OCEAN
# 16378      1849.0       396.0         2.5437          INLAND
# 11943      1425.0       405.0         4.0526          INLAND
#
#        median_house_value
# 6740             359900.0
# 7945             219500.0
# 1706             196600.0
# 10361            286600.0
# 13950            115000.0
# ...                   ...
# 19651            122500.0
# 20355            162500.0
# 5531             352300.0
# 16378             99000.0
# 11943            104500.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize= (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Assuming your dataset is named 'train_data'
# One-hot encode the categorical column 'ocean_proximity'
train_data_encoded = pd.get_dummies(train_data, columns=['ocean_proximity'], drop_first=True)

# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(train_data_encoded.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7212
# INLAND        5218
# NEAR OCEAN    2095
# NEAR BAY      1817
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6740     -118.09     34.12                38.0     7.446585        5.655992
# 7945     -118.14     33.87                44.0     7.415777        5.755742
# 1706     -122.32     37.95                37.0     7.543273        5.869297
# 10361    -117.66     33.57                16.0     8.361241        6.338594
# 13950    -117.07     34.24                21.0     8.470940        6.954639
# ...          ...       ...                 ...          ...             ...
# 19651    -120.87     37.50                 7.0     8.510571        6.893656
# 20355    -118.96     34.19                16.0     7.499977        5.849325
# 5531     -118.41     33.97                44.0     7.933797        6.222576
# 16378    -121.29     38.02                12.0     7.604396        6.056784
# 11943    -117.43     33.95                36.0     7.734121        6.098074
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 6740     6.659294    5.659482         5.6152            359900.0       True
# 7945     6.893656    5.768321         4.3942            219500.0       True
# 1706     6.797940    5.886104         4.4500            196600.0      False
# 10361    7.404279    6.309918         8.0082            286600.0       True
# 13950    5.823046    4.875197         3.9375            115000.0      False
# ...           ...         ...            ...                 ...        ...
# 19651    7.796469    6.807935         3.1042            122500.0      False
# 20355    6.376727    5.693732         1.9811            162500.0       True
# 5531     8.224967    6.163315         4.6176            352300.0       True
# 16378    7.522941    5.983936         2.5437             99000.0      False
# 11943    7.262629    6.006353         4.0526            104500.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 6740    False   False     False       False
# 7945    False   False     False       False
# 1706    False   False      True       False
# 10361   False   False     False       False
# 13950    True   False     False       False
# ...       ...     ...       ...         ...
# 19651    True   False     False       False
# 20355   False   False     False       False
# 5531    False   False     False       False
# 16378    True   False     False       False
# 11943    True   False     False       False
#
# [16346 rows x 14 columns]

# %%
# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(train_data_encoded.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y = 'longitude', data = train_data, hue = 'median_house_value' , palette = "coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/ train_data['total_rooms'] 
train_data['household_rooms'] = train_data['total_rooms']/ train_data['households'] 
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)
test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
test_data['bedroom_ratio'] = test_data['total_bedrooms']/ test_data['total_rooms'] 
test_data['household_rooms'] = test_data['total_rooms']/ test_data['households']

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14644    -117.20     32.78                38.0     7.887209        6.212606
# 4807     -118.34     34.02                50.0     7.067320        5.568345
# 3033     -119.11     35.39                22.0     6.892642        5.176150
# 4356     -118.36     34.09                38.0     7.677400        6.368187
# 6280     -117.92     34.03                35.0     7.201916        5.455321
# ...          ...       ...                 ...          ...             ...
# 1578     -122.03     37.87                21.0     8.166784        6.104793
# 1721     -122.39     38.00                33.0     3.806662        1.945910
# 3903     -118.51     34.19                35.0     7.839132        6.037871
# 9391     -122.54     37.90                48.0     7.820841        6.133398
# 15312    -117.38     33.20                17.0     7.537963        6.366470
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 14644    7.032624    6.208590         4.0057            241600.0      False
# 4807     6.530878    5.564520         3.1442            130300.0       True
# 3033     6.113682    5.141664         3.2500             88900.0      False
# 4356     6.967909    6.359574         2.9643            355300.0       True
# 6280     6.801283    5.379897         4.1118            157300.0       True
# ...           ...         ...            ...                 ...        ...
# 1578     7.242082    6.148468         8.2673            358700.0      False
# 1721     3.178054    2.484907         4.1250            212500.0      False
# 3903     7.057898    6.045005         5.3028            229200.0       True
# 9391     6.843750    6.122493         4.4375            370000.0      False
# 15312    7.161622    6.056784         1.9386            106300.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 14644   False   False     False        True       0.787681         1.270370
# 4807    False   False     False       False       0.787900         1.270068
# 3033     True   False     False       False       0.750967         1.340547
# 4356    False   False     False       False       0.829472         1.207219
# 6280    False   False     False       False       0.757482         1.338672
# ...       ...     ...       ...         ...            ...              ...
# 1578    False   False      True       False       0.747515         1.328263
# 1721    False   False      True       False       0.511185         1.531914
# 3903    False   False     False       False       0.770222         1.296795
# 9391    False   False      True       False       0.784238         1.277395
# 15312   False   False     False        True       0.844588         1.244549
#
# [4087 rows x 16 columns]

# %%
reg.score(x_test,y_test)
# Out:
# 0.6647598276834665

# %%
# Make predictions on the test set
predictions = reg.predict(x_test)

# Create a DataFrame for Seaborn
plot_data = pd.DataFrame({'Actual': y_test, 'Predicted': predictions, 'median_house_value': y_test})

# Create a scatter plot with color based on 'Median_House_Value'
sns.scatterplot(x='Actual', y='Predicted', hue='median_house_value', data=plot_data, palette='coolwarm')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Linear Regression: Actual vs. Predicted")
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error (MSE): {mse}')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 4498884886.405187
# Mean Absolute Error (MAE): 47902.5145901573

# %%
from sklearn.ensemble import RandomForestRegressor

forest= RandomForestRegressor()

forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.8135790713876252
